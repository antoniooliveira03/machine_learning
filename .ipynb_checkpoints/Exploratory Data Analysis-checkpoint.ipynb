# %%
import pandas as pd

# %%
df = pd.read_csv('./project_data/train_data.csv')
df
# Out:
# /var/folders/mm/fxsq_1490x9dd2w76tqvt3kr0000gn/T/ipykernel_41251/1657859846.py:1: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./project_data/train_data.csv')
#        Accident Date  Age at Injury Alternative Dispute Resolution  \
# 0         2019-12-30           31.0                              N
# 1         2019-08-30           46.0                              N
# 2         2019-12-06           40.0                              N
# 3                NaN            NaN                            NaN
# 4         2019-12-30           61.0                              N
# ...              ...            ...                            ...
# 593466           NaN            NaN                            NaN
# 593467    2022-12-13           72.0                              N
# 593468           NaN            NaN                            NaN
# ...
