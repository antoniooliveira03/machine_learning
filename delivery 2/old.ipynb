# %% [markdown]
# # <center>Machine Learning Project Code</center>
#
# <a class="anchor" id="top"></a>
#
# ## <center>*03 - K-Fold*</center>
#
# ** **
#
#
#
# # Table of Contents  <br>
#
#
# 1. [Importing Libraries & Data](#1.-Importing-Libraries-&-Data) <br><br>
#
# 2. [Cross Validation](#2.-Cross-Validation) <br><br>
#
#
# ** **
#
# This notebook will consist of the implementation of Stratified K-Fold. It will use the same techniques to fill missing values and treat outliers as Notebook 02. Feature Selection will only be performed in said notebook, and the selected features there will be used here, due to computational complexity and time constraints.
#
# Data Scientist Manager: António Oliveira, **20211595**
#
# Data Scientist Senior: Tomás Ribeiro, **20240526**
#
# Data Scientist Junior: Gonçalo Pacheco, **20240695**
#
# Data Analyst Senior: Gonçalo Custódio, **20211643**
#
# Data Analyst Junior: Ana Caleiro, **20240696**
#
#
# ** **
#
# # 1. Importing Libraries & Data
# In this section, we set up the foundation for our project by importing the necessary Python libraries and loading the dataset. These libraries provide the tools for data manipulation, visualization, and machine learning modeling throughout the notebook. Additionally, we import the historical claims dataset, which forms the core of our analysis.

# %%
import pandas as pd

# Train-Test Split
from sklearn.model_selection import StratifiedKFold

# Models
import models as mod

# Metrics
import metrics as m

# Visualisations
import viz as v

# Play song
import play_song as s

pd.set_option('display.max_columns', None)

# Suppress Warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Import Data**

# %%
# Load training data
df = pd.read_csv('./data/train_data_EDA.csv', index_col = 'Claim Identifier')

# Load testing data
test1 = pd.read_csv('./data/test_data_EDA.csv', index_col = 'Claim Identifier')

# Display the first 3 rows of the training data
df.head(3)
# Out:
#                   Age at Injury Alternative Dispute Resolution  \
# Claim Identifier
# 5393875                    31.0                              N
# 5393091                    46.0                              N
# 5393889                    40.0                              N
#
#                  Attorney/Representative  Average Weekly Wage  Birth Year  \
# Claim Identifier
# 5393875                                N                 0.00      1988.0
# 5393091                                Y              1745.93      1973.0
# 5393889                                N              1434.80      1979.0
#
#                     C-3 Date                  Carrier Name Carrier Type  \
# Claim Identifier
# 5393875                  NaN    NEW HAMPSHIRE INSURANCE CO  1A. PRIVATE
# 5393091           2020-01-14  ZURICH AMERICAN INSURANCE CO  1A. PRIVATE
# 5393889                  NaN     INDEMNITY INSURANCE CO OF  1A. PRIVATE
#
#                   Claim Injury Type County of Injury COVID-19 Indicator  \
# Claim Identifier
# 5393875                           1     ST. LAWRENCE                  N
# 5393091                           3          WYOMING                  N
# 5393889                           3           ORANGE                  N
#
#                  District Name First Hearing Date Gender  IME-4 Count  \
# Claim Identifier
# 5393875               SYRACUSE                NaN      M          NaN
# 5393091              ROCHESTER         2020-02-21      F          4.0
# 5393889                 ALBANY                NaN      M          NaN
#
#                   Industry Code Medical Fee Region  WCIO Cause of Injury Code  \
# Claim Identifier
# 5393875                    44.0                  I                         27
# 5393091                    23.0                  I                         97
# 5393889                    56.0                 II                         79
#
#                   WCIO Nature of Injury Code  WCIO Part Of Body Code  \
# Claim Identifier
# 5393875                                   10                      62
# 5393091                                   49                      38
# 5393889                                    7                      10
#
#                   Number of Dependents  Gender Enc  Accident Date Year  \
# Claim Identifier
# 5393875                            1.0           0              2019.0
# 5393091                            4.0           1              2019.0
# 5393889                            6.0           0              2019.0
#
#                   Accident Date Month  Accident Date Day  \
# Claim Identifier
# 5393875                          12.0               30.0
# 5393091                           8.0               30.0
# 5393889                          12.0                6.0
#
#                   Accident Date Day of Week  Assembly Date Year  \
# Claim Identifier
# 5393875                                 0.0                2020
# 5393091                                 4.0                2020
# 5393889                                 4.0                2020
#
#                   Assembly Date Month  Assembly Date Day  \
# Claim Identifier
# 5393875                             1                  1
# 5393091                             1                  1
# 5393889                             1                  1
#
#                   Assembly Date Day of Week  C-2 Date Year  C-2 Date Month  \
# Claim Identifier
# 5393875                                   2         2019.0            12.0
# 5393091                                   2         2020.0             1.0
# 5393889                                   2         2020.0             1.0
#
#                   C-2 Date Day  C-2 Date Day of Week  \
# Claim Identifier
# 5393875                   31.0                   1.0
# 5393091                    1.0                   2.0
# 5393889                    1.0                   2.0
#
#                   Accident to Assembly Time  Assembly to C-2 Time  \
# Claim Identifier
# 5393875                                 2.0                   1.0
# 5393091                               124.0                   0.0
# 5393889                                26.0                   0.0
#
#                   Accident to C-2 Time  WCIO Codes  Insurance  Zip Code Valid  \
# Claim Identifier
# 5393875                            1.0      271062          1               0
# 5393091                          124.0      974938          1               0
# 5393889                           26.0       79710          1               0
#
#                                  Industry Sector  Age Group
# Claim Identifier
# 5393875                     Retail and Wholesale          1
# 5393091           Manufacturing and Construction          1
# 5393889                        Business Services          1

# %% [markdown]
# # 2. Cross Validation
#
# <a href="#top">Top &#129033;</a>

# %%
# Split the DataFrame into features (X) and target variable (y)
X = df.drop('Claim Injury Type', axis=1) 
y = df['Claim Injury Type']

# %% [markdown]
# **Final Columns**

# %%
num = [
    "Accident Date Day",
    "Accident Date Month",
    "Accident to Assembly Time",
    "Accident to C-2 Time",
    "Age at Injury",
    "Assembly Date Year",
    "Assembly to C-2 Time",
    "Average Weekly Wage",
    "Average Weekly Wage Sqrt",
    "Birth Year",
    "C-2 Date Day",
    "C-2 Date Month",
    "C-2 Date Year",
    "IME-4 Count",
    "IME-4 Count Log"]

categ = [
    "Accident Date Day of Week", 
    "Assembly Date Day of Week",
    "Age Group",
    "Alternative Dispute Resolution Enc",
    "Attorney/Representative Enc",
    "Carrier Name Enc",
    "Carrier Type Enc",
    "C-2 Date Day of Week",
    "C-3 Date Binary",
    "COVID-19 Indicator Enc",
    "County of Injury Enc",
    "District Name Enc",
    "First Hearing Date Binary",
    "Gender Enc",
    "Industry Code",
    "Industry Sector Enc",
    "Medical Fee Region Enc",
    "WCIO Cause of Injury Code",
    "WCIO Codes",
    "WCIO Nature of Injury Code",
    "WCIO Part Of Body Code"]

cols = num + categ

# %% [markdown]
# **Stratified K-Fold**

# %%
method = StratifiedKFold(n_splits=15, shuffle=True, random_state=42)

# %% [markdown]
# **XGB, RF & LGBM**

# %%
XGB_freq_no_out_15f = mod.k_fold(method, X, y, test1, 'XGB', params = {},
                              enc = 'freq', outliers = True,
                              file_name = 'XGB_freq_no_out_15f')

XGB_freq_out_15f = mod.k_fold(method, X, y, test1, 'XGB', params = {},
                              enc = 'freq', outliers = False,
                              file_name = 'XGB_freq_out_15f')

XGB_count_no_out_15f = mod.k_fold(method, X, y, test1, 'XGB', params = {},
                              enc = 'count', outliers = True,
                              file_name = 'XGB_count_no_out_15f')

XGB_count_out_15f = mod.k_fold(method, X, y, test1, 'XGB', params = {},
                              enc = 'count', outliers = False,
                              file_name = 'XGB_count_out_15f')
# Out:
# This Fold took 1.52 minutes
# This Fold took 1.5 minutes
# This Fold took 1.5 minutes
# This Fold took 1.56 minutes
# This Fold took 1.61 minutes
# This Fold took 1.55 minutes
# This Fold took 1.57 minutes
# This Fold took 1.51 minutes
# This Fold took 1.52 minutes
# This Fold took 1.52 minutes
# This Fold took 1.53 minutes
# This Fold took 1.52 minutes
# This Fold took 1.53 minutes
# This Fold took 1.54 minutes
# This Fold took 1.55 minutes
# This Fold took 1.45 minutes
# This Fold took 1.4 minutes
# This Fold took 1.48 minutes
# This Fold took 1.51 minutes
# This Fold took 1.5 minutes
# This Fold took 1.44 minutes
# This Fold took 1.43 minutes
# This Fold took 1.44 minutes
# This Fold took 1.43 minutes
# This Fold took 1.46 minutes
# This Fold took 1.45 minutes
# This Fold took 1.46 minutes
# This Fold took 1.44 minutes
# This Fold took 1.44 minutes
# This Fold took 1.44 minutes
# This Fold took 1.2 minutes
# This Fold took 1.2 minutes
# This Fold took 1.21 minutes
# This Fold took 1.2 minutes
# This Fold took 1.2 minutes
# This Fold took 1.21 minutes
# This Fold took 1.21 minutes
# This Fold took 1.21 minutes
# This Fold took 1.21 minutes
# This Fold took 1.21 minutes
# This Fold took 1.2 minutes
# This Fold took 1.21 minutes
# This Fold took 1.2 minutes
# This Fold took 1.21 minutes
# This Fold took 1.21 minutes
# This Fold took 1.19 minutes
# This Fold took 1.19 minutes
# This Fold took 1.2 minutes
# This Fold took 1.2 minutes
# This Fold took 1.2 minutes
# This Fold took 1.22 minutes
# This Fold took 1.21 minutes
# This Fold took 1.2 minutes
# This Fold took 1.2 minutes
# This Fold took 1.2 minutes
# This Fold took 1.21 minutes
# This Fold took 1.2 minutes
# This Fold took 1.2 minutes
# This Fold took 1.18 minutes
# This Fold took 1.2 minutes

# %%
RF_freq_no_out_15f = mod.k_fold(method, X, y, test1, 'RF', params = {},
                              enc = 'freq', outliers = True,
                              file_name = 'RF_freq_no_out_15f')

RF_freq_out_15f = mod.k_fold(method, X, y, test1, 'RF', params = {},
                              enc = 'freq', outliers = False,
                              file_name = 'RF_freq_out_15f')

RF_count_no_out_15f = mod.k_fold(method, X, y, test1, 'RF', params = {},
                              enc = 'count', outliers = True,
                              file_name = 'RF_count_no_out_15f')

RF_count_out_15f = mod.k_fold(method, X, y, test1, 'RF', params = {},
                              enc = 'count', outliers = False,
                              file_name = 'RF_count_out_15f')
# Out:
# This Fold took 4.99 minutes
# This Fold took 4.93 minutes
# This Fold took 4.72 minutes
# This Fold took 4.72 minutes
# This Fold took 4.76 minutes
# This Fold took 4.76 minutes
# This Fold took 4.81 minutes
# This Fold took 5.0 minutes
# This Fold took 4.74 minutes
# This Fold took 4.75 minutes
# This Fold took 4.81 minutes
# This Fold took 4.83 minutes
# This Fold took 4.86 minutes
# This Fold took 4.89 minutes
# This Fold took 4.93 minutes
# This Fold took 4.69 minutes
# This Fold took 4.74 minutes
# This Fold took 4.72 minutes
# This Fold took 4.75 minutes
# This Fold took 4.78 minutes
# This Fold took 4.73 minutes
# This Fold took 4.6 minutes
# This Fold took 4.56 minutes
# This Fold took 4.58 minutes
# This Fold took 4.57 minutes
# This Fold took 4.57 minutes
# This Fold took 4.58 minutes
# This Fold took 4.6 minutes
# This Fold took 4.57 minutes
# This Fold took 4.64 minutes
# This Fold took 4.65 minutes
# This Fold took 4.68 minutes
# This Fold took 4.66 minutes
# This Fold took 4.66 minutes
# This Fold took 4.88 minutes
# This Fold took 4.78 minutes
# This Fold took 4.91 minutes
# This Fold took 4.49 minutes
# This Fold took 4.88 minutes
# This Fold took 4.88 minutes
# This Fold took 4.94 minutes
# This Fold took 4.94 minutes
# This Fold took 4.96 minutes
# This Fold took 4.63 minutes
# This Fold took 4.53 minutes
# This Fold took 4.13 minutes
# This Fold took 4.1 minutes
# This Fold took 4.27 minutes
# This Fold took 4.37 minutes
# This Fold took 4.4 minutes
# This Fold took 4.44 minutes
# This Fold took 4.5 minutes
# This Fold took 4.49 minutes
# This Fold took 4.28 minutes
# This Fold took 4.45 minutes
# This Fold took 4.52 minutes
# This Fold took 4.57 minutes
# This Fold took 4.54 minutes
# This Fold took 4.54 minutes
# This Fold took 4.57 minutes

# %%
LGBM_freq_no_out_15f = mod.k_fold(method, X, y, test1, 'LGBM', params = {},
                              enc = 'freq', outliers = True,
                              file_name = 'LGBM_freq_no_out_15f')

LGBM_freq_out_15f = mod.k_fold(method, X, y, test1, 'LGBM', params = {},
                              enc = 'freq', outliers = False,
                              file_name = 'LGBM_freq_out_15f')

LGBM_count_no_out_15f = mod.k_fold(method, X, y, test1, 'LGBM', params = {},
                              enc = 'count', outliers = True,
                              file_name = 'LGBM_count_no_out_15f')

LGBM_count_out_15f = mod.k_fold(method, X, y, test1, 'LGBM', params = {},
                              enc = 'count', outliers = False,
                              file_name = 'LGBM_count_out_15f')
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031384 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2749
# [LightGBM] [Info] Number of data points in the train set: 530485, number of used features: 50
# [LightGBM] [Info] Start training from score -3.876260
# [LightGBM] [Info] Start training from score -0.676645
# [LightGBM] [Info] Start training from score -2.114487
# [LightGBM] [Info] Start training from score -1.357548
# [LightGBM] [Info] Start training from score -2.469955
# [LightGBM] [Info] Start training from score -4.908210
# [LightGBM] [Info] Start training from score -8.692911
# [LightGBM] [Info] Start training from score -7.101614
# This Fold took 1.37 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.034732 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2746
# [LightGBM] [Info] Number of data points in the train set: 530531, number of used features: 50
# [LightGBM] [Info] Start training from score -3.875165
# [LightGBM] [Info] Start training from score -0.676650
# [LightGBM] [Info] Start training from score -2.114480
# [LightGBM] [Info] Start training from score -1.357598
# [LightGBM] [Info] Start training from score -2.470020
# [LightGBM] [Info] Start training from score -4.908552
# [LightGBM] [Info] Start training from score -8.692997
# [LightGBM] [Info] Start training from score -7.101700
# This Fold took 1.37 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.041207 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2738
# [LightGBM] [Info] Number of data points in the train set: 530507, number of used features: 50
# [LightGBM] [Info] Start training from score -3.875574
# [LightGBM] [Info] Start training from score -0.676671
# [LightGBM] [Info] Start training from score -2.114450
# [LightGBM] [Info] Start training from score -1.357589
# [LightGBM] [Info] Start training from score -2.469841
# [LightGBM] [Info] Start training from score -4.908762
# [LightGBM] [Info] Start training from score -8.692952
# [LightGBM] [Info] Start training from score -7.101655
# This Fold took 1.37 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.026559 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2748
# [LightGBM] [Info] Number of data points in the train set: 530496, number of used features: 50
# [LightGBM] [Info] Start training from score -3.876827
# [LightGBM] [Info] Start training from score -0.676662
# [LightGBM] [Info] Start training from score -2.114492
# [LightGBM] [Info] Start training from score -1.357510
# [LightGBM] [Info] Start training from score -2.469776
# [LightGBM] [Info] Start training from score -4.908742
# [LightGBM] [Info] Start training from score -8.692931
# [LightGBM] [Info] Start training from score -7.101635
# This Fold took 1.36 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.030759 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2744
# [LightGBM] [Info] Number of data points in the train set: 530465, number of used features: 50
# [LightGBM] [Info] Start training from score -3.876768
# [LightGBM] [Info] Start training from score -0.676625
# [LightGBM] [Info] Start training from score -2.114449
# [LightGBM] [Info] Start training from score -1.357598
# [LightGBM] [Info] Start training from score -2.469851
# [LightGBM] [Info] Start training from score -4.908173
# [LightGBM] [Info] Start training from score -8.692873
# [LightGBM] [Info] Start training from score -7.101576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# This Fold took 1.38 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.028649 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2737
# [LightGBM] [Info] Number of data points in the train set: 530530, number of used features: 50
# [LightGBM] [Info] Start training from score -3.875527
# [LightGBM] [Info] Start training from score -0.676607
# [LightGBM] [Info] Start training from score -2.114494
# [LightGBM] [Info] Start training from score -1.357654
# [LightGBM] [Info] Start training from score -2.469996
# [LightGBM] [Info] Start training from score -4.908806
# [LightGBM] [Info] Start training from score -8.681822
# [LightGBM] [Info] Start training from score -7.101699
# This Fold took 1.41 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.029043 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2743
# [LightGBM] [Info] Number of data points in the train set: 530515, number of used features: 50
# [LightGBM] [Info] Start training from score -3.876408
# [LightGBM] [Info] Start training from score -0.676657
# [LightGBM] [Info] Start training from score -2.114543
# [LightGBM] [Info] Start training from score -1.357568
# [LightGBM] [Info] Start training from score -2.469745
# [LightGBM] [Info] Start training from score -4.908012
# [LightGBM] [Info] Start training from score -8.681794
# [LightGBM] [Info] Start training from score -7.101670
# This Fold took 1.36 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.028714 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2739
# [LightGBM] [Info] Number of data points in the train set: 530512, number of used features: 50
# [LightGBM] [Info] Start training from score -3.877221
# [LightGBM] [Info] Start training from score -0.676610
# [LightGBM] [Info] Start training from score -2.114553
# [LightGBM] [Info] Start training from score -1.357533
# [LightGBM] [Info] Start training from score -2.469917
# [LightGBM] [Info] Start training from score -4.908517
# [LightGBM] [Info] Start training from score -8.670738
# [LightGBM] [Info] Start training from score -7.099379
# This Fold took 1.37 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.028428 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2743
# [LightGBM] [Info] Number of data points in the train set: 530486, number of used features: 50
# [LightGBM] [Info] Start training from score -3.874899
# [LightGBM] [Info] Start training from score -0.676591
# [LightGBM] [Info] Start training from score -2.114457
# [LightGBM] [Info] Start training from score -1.357769
# [LightGBM] [Info] Start training from score -2.469957
# [LightGBM] [Info] Start training from score -4.908468
# [LightGBM] [Info] Start training from score -8.681739
# [LightGBM] [Info] Start training from score -7.103907
# This Fold took 1.37 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.025528 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2742
# [LightGBM] [Info] Number of data points in the train set: 530488, number of used features: 50
# [LightGBM] [Info] Start training from score -3.875993
# [LightGBM] [Info] Start training from score -0.676628
# [LightGBM] [Info] Start training from score -2.114571
# [LightGBM] [Info] Start training from score -1.357546
# [LightGBM] [Info] Start training from score -2.469983
# [LightGBM] [Info] Start training from score -4.908727
# [LightGBM] [Info] Start training from score -8.681743
# [LightGBM] [Info] Start training from score -7.101619
# This Fold took 1.36 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.054226 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2740
# [LightGBM] [Info] Number of data points in the train set: 530494, number of used features: 50
# [LightGBM] [Info] Start training from score -3.876368
# [LightGBM] [Info] Start training from score -0.676647
# [LightGBM] [Info] Start training from score -2.114613
# [LightGBM] [Info] Start training from score -1.357477
# [LightGBM] [Info] Start training from score -2.469928
# [LightGBM] [Info] Start training from score -4.908483
# [LightGBM] [Info] Start training from score -8.681754
# [LightGBM] [Info] Start training from score -7.103922
# This Fold took 1.37 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.032040 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2744
# [LightGBM] [Info] Number of data points in the train set: 530521, number of used features: 50
# [LightGBM] [Info] Start training from score -3.875964
# [LightGBM] [Info] Start training from score -0.676631
# [LightGBM] [Info] Start training from score -2.114648
# [LightGBM] [Info] Start training from score -1.357491
# [LightGBM] [Info] Start training from score -2.470046
# [LightGBM] [Info] Start training from score -4.908278
# [LightGBM] [Info] Start training from score -8.681805
# [LightGBM] [Info] Start training from score -7.103973
# This Fold took 1.36 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.028721 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2748
# [LightGBM] [Info] Number of data points in the train set: 530534, number of used features: 50
# [LightGBM] [Info] Start training from score -3.875898
# [LightGBM] [Info] Start training from score -0.676607
# [LightGBM] [Info] Start training from score -2.114501
# [LightGBM] [Info] Start training from score -1.357596
# [LightGBM] [Info] Start training from score -2.470092
# [LightGBM] [Info] Start training from score -4.908303
# [LightGBM] [Info] Start training from score -8.681830
# [LightGBM] [Info] Start training from score -7.103997
# This Fold took 1.36 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.028610 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2745
# [LightGBM] [Info] Number of data points in the train set: 530495, number of used features: 50
# [LightGBM] [Info] Start training from score -3.876097
# [LightGBM] [Info] Start training from score -0.676667
# [LightGBM] [Info] Start training from score -2.114615
# [LightGBM] [Info] Start training from score -1.357471
# [LightGBM] [Info] Start training from score -2.469885
# [LightGBM] [Info] Start training from score -4.908484
# [LightGBM] [Info] Start training from score -8.692929
# [LightGBM] [Info] Start training from score -7.101633
# This Fold took 1.36 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.027367 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2744
# [LightGBM] [Info] Number of data points in the train set: 530527, number of used features: 50
# [LightGBM] [Info] Start training from score -3.876248
# [LightGBM] [Info] Start training from score -0.676690
# [LightGBM] [Info] Start training from score -2.114613
# [LightGBM] [Info] Start training from score -1.357363
# [LightGBM] [Info] Start training from score -2.470057
# [LightGBM] [Info] Start training from score -4.908290
# [LightGBM] [Info] Start training from score -8.692990
# [LightGBM] [Info] Start training from score -7.101693
# This Fold took 1.36 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.047036 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2520
# [LightGBM] [Info] Number of data points in the train set: 535756, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828888
# [LightGBM] [Info] Start training from score -0.679083
# [LightGBM] [Info] Start training from score -2.119933
# [LightGBM] [Info] Start training from score -1.352036
# [LightGBM] [Info] Start training from score -2.475662
# [LightGBM] [Info] Start training from score -4.914785
# [LightGBM] [Info] Start training from score -8.691624
# [LightGBM] [Info] Start training from score -7.106935
# This Fold took 1.35 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.026871 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2518
# [LightGBM] [Info] Number of data points in the train set: 535756, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828888
# [LightGBM] [Info] Start training from score -0.679083
# [LightGBM] [Info] Start training from score -2.119933
# [LightGBM] [Info] Start training from score -1.352036
# [LightGBM] [Info] Start training from score -2.475640
# [LightGBM] [Info] Start training from score -4.915039
# [LightGBM] [Info] Start training from score -8.691624
# [LightGBM] [Info] Start training from score -7.106935
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# This Fold took 1.34 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.023582 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2517
# [LightGBM] [Info] Number of data points in the train set: 535756, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828888
# [LightGBM] [Info] Start training from score -0.679083
# [LightGBM] [Info] Start training from score -2.119933
# [LightGBM] [Info] Start training from score -1.352036
# [LightGBM] [Info] Start training from score -2.475640
# [LightGBM] [Info] Start training from score -4.915039
# [LightGBM] [Info] Start training from score -8.691624
# [LightGBM] [Info] Start training from score -7.106935
# This Fold took 1.33 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.025523 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2518
# [LightGBM] [Info] Number of data points in the train set: 535756, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828888
# [LightGBM] [Info] Start training from score -0.679080
# [LightGBM] [Info] Start training from score -2.119933
# [LightGBM] [Info] Start training from score -1.352043
# [LightGBM] [Info] Start training from score -2.475640
# [LightGBM] [Info] Start training from score -4.915039
# [LightGBM] [Info] Start training from score -8.691624
# [LightGBM] [Info] Start training from score -7.106935
# This Fold took 1.36 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.026833 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2512
# [LightGBM] [Info] Number of data points in the train set: 535756, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828888
# [LightGBM] [Info] Start training from score -0.679080
# [LightGBM] [Info] Start training from score -2.119933
# [LightGBM] [Info] Start training from score -1.352043
# [LightGBM] [Info] Start training from score -2.475640
# [LightGBM] [Info] Start training from score -4.915039
# [LightGBM] [Info] Start training from score -8.691624
# [LightGBM] [Info] Start training from score -7.106935
# This Fold took 1.37 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.026876 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2518
# [LightGBM] [Info] Number of data points in the train set: 535757, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828890
# [LightGBM] [Info] Start training from score -0.679082
# [LightGBM] [Info] Start training from score -2.119934
# [LightGBM] [Info] Start training from score -1.352045
# [LightGBM] [Info] Start training from score -2.475641
# [LightGBM] [Info] Start training from score -4.915041
# [LightGBM] [Info] Start training from score -8.680576
# [LightGBM] [Info] Start training from score -7.106937
# This Fold took 1.36 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.027413 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2511
# [LightGBM] [Info] Number of data points in the train set: 535757, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828890
# [LightGBM] [Info] Start training from score -0.679082
# [LightGBM] [Info] Start training from score -2.119919
# [LightGBM] [Info] Start training from score -1.352045
# [LightGBM] [Info] Start training from score -2.475664
# [LightGBM] [Info] Start training from score -4.915041
# [LightGBM] [Info] Start training from score -8.680576
# [LightGBM] [Info] Start training from score -7.106937
# This Fold took 1.36 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.050555 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2523
# [LightGBM] [Info] Number of data points in the train set: 535757, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828890
# [LightGBM] [Info] Start training from score -0.679082
# [LightGBM] [Info] Start training from score -2.119919
# [LightGBM] [Info] Start training from score -1.352045
# [LightGBM] [Info] Start training from score -2.475664
# [LightGBM] [Info] Start training from score -4.915041
# [LightGBM] [Info] Start training from score -8.680576
# [LightGBM] [Info] Start training from score -7.106937
# This Fold took 1.36 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.025886 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2515
# [LightGBM] [Info] Number of data points in the train set: 535757, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828804
# [LightGBM] [Info] Start training from score -0.679082
# [LightGBM] [Info] Start training from score -2.119919
# [LightGBM] [Info] Start training from score -1.352045
# [LightGBM] [Info] Start training from score -2.475664
# [LightGBM] [Info] Start training from score -4.915041
# [LightGBM] [Info] Start training from score -8.680576
# [LightGBM] [Info] Start training from score -7.109217
# This Fold took 1.37 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.026166 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2518
# [LightGBM] [Info] Number of data points in the train set: 535757, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828804
# [LightGBM] [Info] Start training from score -0.679082
# [LightGBM] [Info] Start training from score -2.119919
# [LightGBM] [Info] Start training from score -1.352045
# [LightGBM] [Info] Start training from score -2.475664
# [LightGBM] [Info] Start training from score -4.915041
# [LightGBM] [Info] Start training from score -8.680576
# [LightGBM] [Info] Start training from score -7.109217
# This Fold took 1.38 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.023545 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2513
# [LightGBM] [Info] Number of data points in the train set: 535757, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828804
# [LightGBM] [Info] Start training from score -0.679082
# [LightGBM] [Info] Start training from score -2.119934
# [LightGBM] [Info] Start training from score -1.352038
# [LightGBM] [Info] Start training from score -2.475664
# [LightGBM] [Info] Start training from score -4.915041
# [LightGBM] [Info] Start training from score -8.680576
# [LightGBM] [Info] Start training from score -7.109217
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# This Fold took 1.37 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.022698 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2518
# [LightGBM] [Info] Number of data points in the train set: 535757, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828804
# [LightGBM] [Info] Start training from score -0.679082
# [LightGBM] [Info] Start training from score -2.119934
# [LightGBM] [Info] Start training from score -1.352038
# [LightGBM] [Info] Start training from score -2.475664
# [LightGBM] [Info] Start training from score -4.915041
# [LightGBM] [Info] Start training from score -8.680576
# [LightGBM] [Info] Start training from score -7.109217
# This Fold took 1.37 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.025246 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2509
# [LightGBM] [Info] Number of data points in the train set: 535757, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828890
# [LightGBM] [Info] Start training from score -0.679082
# [LightGBM] [Info] Start training from score -2.119934
# [LightGBM] [Info] Start training from score -1.352038
# [LightGBM] [Info] Start training from score -2.475664
# [LightGBM] [Info] Start training from score -4.914787
# [LightGBM] [Info] Start training from score -8.680576
# [LightGBM] [Info] Start training from score -7.109217
# This Fold took 1.33 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.025315 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2520
# [LightGBM] [Info] Number of data points in the train set: 535757, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828890
# [LightGBM] [Info] Start training from score -0.679082
# [LightGBM] [Info] Start training from score -2.119934
# [LightGBM] [Info] Start training from score -1.352038
# [LightGBM] [Info] Start training from score -2.475664
# [LightGBM] [Info] Start training from score -4.914787
# [LightGBM] [Info] Start training from score -8.691626
# [LightGBM] [Info] Start training from score -7.106937
# This Fold took 1.35 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.046377 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2509
# [LightGBM] [Info] Number of data points in the train set: 535757, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828890
# [LightGBM] [Info] Start training from score -0.679082
# [LightGBM] [Info] Start training from score -2.119934
# [LightGBM] [Info] Start training from score -1.352038
# [LightGBM] [Info] Start training from score -2.475664
# [LightGBM] [Info] Start training from score -4.914787
# [LightGBM] [Info] Start training from score -8.691626
# [LightGBM] [Info] Start training from score -7.106937
# This Fold took 1.38 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031158 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2749
# [LightGBM] [Info] Number of data points in the train set: 530485, number of used features: 50
# [LightGBM] [Info] Start training from score -3.876260
# [LightGBM] [Info] Start training from score -0.676645
# [LightGBM] [Info] Start training from score -2.114487
# [LightGBM] [Info] Start training from score -1.357548
# [LightGBM] [Info] Start training from score -2.469955
# [LightGBM] [Info] Start training from score -4.908210
# [LightGBM] [Info] Start training from score -8.692911
# [LightGBM] [Info] Start training from score -7.101614
# This Fold took 1.14 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.027315 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2746
# [LightGBM] [Info] Number of data points in the train set: 530531, number of used features: 50
# [LightGBM] [Info] Start training from score -3.875165
# [LightGBM] [Info] Start training from score -0.676650
# [LightGBM] [Info] Start training from score -2.114480
# [LightGBM] [Info] Start training from score -1.357598
# [LightGBM] [Info] Start training from score -2.470020
# [LightGBM] [Info] Start training from score -4.908552
# [LightGBM] [Info] Start training from score -8.692997
# [LightGBM] [Info] Start training from score -7.101700
# This Fold took 1.14 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.028669 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2738
# [LightGBM] [Info] Number of data points in the train set: 530507, number of used features: 50
# [LightGBM] [Info] Start training from score -3.875574
# [LightGBM] [Info] Start training from score -0.676671
# [LightGBM] [Info] Start training from score -2.114450
# [LightGBM] [Info] Start training from score -1.357589
# [LightGBM] [Info] Start training from score -2.469841
# [LightGBM] [Info] Start training from score -4.908762
# [LightGBM] [Info] Start training from score -8.692952
# [LightGBM] [Info] Start training from score -7.101655
# This Fold took 1.12 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031552 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2748
# [LightGBM] [Info] Number of data points in the train set: 530496, number of used features: 50
# [LightGBM] [Info] Start training from score -3.876827
# [LightGBM] [Info] Start training from score -0.676662
# [LightGBM] [Info] Start training from score -2.114492
# [LightGBM] [Info] Start training from score -1.357510
# [LightGBM] [Info] Start training from score -2.469776
# [LightGBM] [Info] Start training from score -4.908742
# [LightGBM] [Info] Start training from score -8.692931
# [LightGBM] [Info] Start training from score -7.101635
# This Fold took 1.1 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.026204 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2744
# [LightGBM] [Info] Number of data points in the train set: 530465, number of used features: 50
# [LightGBM] [Info] Start training from score -3.876768
# [LightGBM] [Info] Start training from score -0.676625
# [LightGBM] [Info] Start training from score -2.114449
# [LightGBM] [Info] Start training from score -1.357598
# [LightGBM] [Info] Start training from score -2.469851
# [LightGBM] [Info] Start training from score -4.908173
# [LightGBM] [Info] Start training from score -8.692873
# [LightGBM] [Info] Start training from score -7.101576
# This Fold took 1.12 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.027372 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2737
# [LightGBM] [Info] Number of data points in the train set: 530530, number of used features: 50
# [LightGBM] [Info] Start training from score -3.875527
# [LightGBM] [Info] Start training from score -0.676607
# [LightGBM] [Info] Start training from score -2.114494
# [LightGBM] [Info] Start training from score -1.357654
# [LightGBM] [Info] Start training from score -2.469996
# [LightGBM] [Info] Start training from score -4.908806
# [LightGBM] [Info] Start training from score -8.681822
# [LightGBM] [Info] Start training from score -7.101699
# This Fold took 1.09 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.028558 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2743
# [LightGBM] [Info] Number of data points in the train set: 530515, number of used features: 50
# [LightGBM] [Info] Start training from score -3.876408
# [LightGBM] [Info] Start training from score -0.676657
# [LightGBM] [Info] Start training from score -2.114543
# [LightGBM] [Info] Start training from score -1.357568
# [LightGBM] [Info] Start training from score -2.469745
# [LightGBM] [Info] Start training from score -4.908012
# [LightGBM] [Info] Start training from score -8.681794
# [LightGBM] [Info] Start training from score -7.101670
# This Fold took 1.1 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.153453 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2739
# [LightGBM] [Info] Number of data points in the train set: 530512, number of used features: 50
# [LightGBM] [Info] Start training from score -3.877221
# [LightGBM] [Info] Start training from score -0.676610
# [LightGBM] [Info] Start training from score -2.114553
# [LightGBM] [Info] Start training from score -1.357533
# [LightGBM] [Info] Start training from score -2.469917
# [LightGBM] [Info] Start training from score -4.908517
# [LightGBM] [Info] Start training from score -8.670738
# [LightGBM] [Info] Start training from score -7.099379
# This Fold took 1.2 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.028082 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2743
# [LightGBM] [Info] Number of data points in the train set: 530486, number of used features: 50
# [LightGBM] [Info] Start training from score -3.874899
# [LightGBM] [Info] Start training from score -0.676591
# [LightGBM] [Info] Start training from score -2.114457
# [LightGBM] [Info] Start training from score -1.357769
# [LightGBM] [Info] Start training from score -2.469957
# [LightGBM] [Info] Start training from score -4.908468
# [LightGBM] [Info] Start training from score -8.681739
# [LightGBM] [Info] Start training from score -7.103907
# This Fold took 1.12 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.028202 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2742
# [LightGBM] [Info] Number of data points in the train set: 530488, number of used features: 50
# [LightGBM] [Info] Start training from score -3.875993
# [LightGBM] [Info] Start training from score -0.676628
# [LightGBM] [Info] Start training from score -2.114571
# [LightGBM] [Info] Start training from score -1.357546
# [LightGBM] [Info] Start training from score -2.469983
# [LightGBM] [Info] Start training from score -4.908727
# [LightGBM] [Info] Start training from score -8.681743
# [LightGBM] [Info] Start training from score -7.101619
# This Fold took 1.12 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.039318 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2740
# [LightGBM] [Info] Number of data points in the train set: 530494, number of used features: 50
# [LightGBM] [Info] Start training from score -3.876368
# [LightGBM] [Info] Start training from score -0.676647
# [LightGBM] [Info] Start training from score -2.114613
# [LightGBM] [Info] Start training from score -1.357477
# [LightGBM] [Info] Start training from score -2.469928
# [LightGBM] [Info] Start training from score -4.908483
# [LightGBM] [Info] Start training from score -8.681754
# [LightGBM] [Info] Start training from score -7.103922
# This Fold took 1.12 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.028619 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2744
# [LightGBM] [Info] Number of data points in the train set: 530521, number of used features: 50
# [LightGBM] [Info] Start training from score -3.875964
# [LightGBM] [Info] Start training from score -0.676631
# [LightGBM] [Info] Start training from score -2.114648
# [LightGBM] [Info] Start training from score -1.357491
# [LightGBM] [Info] Start training from score -2.470046
# [LightGBM] [Info] Start training from score -4.908278
# [LightGBM] [Info] Start training from score -8.681805
# [LightGBM] [Info] Start training from score -7.103973
# This Fold took 1.08 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.027156 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2748
# [LightGBM] [Info] Number of data points in the train set: 530534, number of used features: 50
# [LightGBM] [Info] Start training from score -3.875898
# [LightGBM] [Info] Start training from score -0.676607
# [LightGBM] [Info] Start training from score -2.114501
# [LightGBM] [Info] Start training from score -1.357596
# [LightGBM] [Info] Start training from score -2.470092
# [LightGBM] [Info] Start training from score -4.908303
# [LightGBM] [Info] Start training from score -8.681830
# [LightGBM] [Info] Start training from score -7.103997
# This Fold took 1.08 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.026464 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2745
# [LightGBM] [Info] Number of data points in the train set: 530495, number of used features: 50
# [LightGBM] [Info] Start training from score -3.876097
# [LightGBM] [Info] Start training from score -0.676667
# [LightGBM] [Info] Start training from score -2.114615
# [LightGBM] [Info] Start training from score -1.357471
# [LightGBM] [Info] Start training from score -2.469885
# [LightGBM] [Info] Start training from score -4.908484
# [LightGBM] [Info] Start training from score -8.692929
# [LightGBM] [Info] Start training from score -7.101633
# This Fold took 1.1 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.029060 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2744
# [LightGBM] [Info] Number of data points in the train set: 530527, number of used features: 50
# [LightGBM] [Info] Start training from score -3.876248
# [LightGBM] [Info] Start training from score -0.676690
# [LightGBM] [Info] Start training from score -2.114613
# [LightGBM] [Info] Start training from score -1.357363
# [LightGBM] [Info] Start training from score -2.470057
# [LightGBM] [Info] Start training from score -4.908290
# [LightGBM] [Info] Start training from score -8.692990
# [LightGBM] [Info] Start training from score -7.101693
# This Fold took 1.11 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.046995 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2520
# [LightGBM] [Info] Number of data points in the train set: 535756, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828888
# [LightGBM] [Info] Start training from score -0.679083
# [LightGBM] [Info] Start training from score -2.119933
# [LightGBM] [Info] Start training from score -1.352036
# [LightGBM] [Info] Start training from score -2.475662
# [LightGBM] [Info] Start training from score -4.914785
# [LightGBM] [Info] Start training from score -8.691624
# [LightGBM] [Info] Start training from score -7.106935
# This Fold took 1.09 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.025048 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2518
# [LightGBM] [Info] Number of data points in the train set: 535756, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828888
# [LightGBM] [Info] Start training from score -0.679083
# [LightGBM] [Info] Start training from score -2.119933
# [LightGBM] [Info] Start training from score -1.352036
# [LightGBM] [Info] Start training from score -2.475640
# [LightGBM] [Info] Start training from score -4.915039
# [LightGBM] [Info] Start training from score -8.691624
# [LightGBM] [Info] Start training from score -7.106935
# This Fold took 1.1 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.027215 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2517
# [LightGBM] [Info] Number of data points in the train set: 535756, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828888
# [LightGBM] [Info] Start training from score -0.679083
# [LightGBM] [Info] Start training from score -2.119933
# [LightGBM] [Info] Start training from score -1.352036
# [LightGBM] [Info] Start training from score -2.475640
# [LightGBM] [Info] Start training from score -4.915039
# [LightGBM] [Info] Start training from score -8.691624
# [LightGBM] [Info] Start training from score -7.106935
# This Fold took 1.09 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.028058 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2518
# [LightGBM] [Info] Number of data points in the train set: 535756, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828888
# [LightGBM] [Info] Start training from score -0.679080
# [LightGBM] [Info] Start training from score -2.119933
# [LightGBM] [Info] Start training from score -1.352043
# [LightGBM] [Info] Start training from score -2.475640
# [LightGBM] [Info] Start training from score -4.915039
# [LightGBM] [Info] Start training from score -8.691624
# [LightGBM] [Info] Start training from score -7.106935
# This Fold took 1.1 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.028354 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2512
# [LightGBM] [Info] Number of data points in the train set: 535756, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828888
# [LightGBM] [Info] Start training from score -0.679080
# [LightGBM] [Info] Start training from score -2.119933
# [LightGBM] [Info] Start training from score -1.352043
# [LightGBM] [Info] Start training from score -2.475640
# [LightGBM] [Info] Start training from score -4.915039
# [LightGBM] [Info] Start training from score -8.691624
# [LightGBM] [Info] Start training from score -7.106935
# This Fold took 1.1 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.022615 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2518
# [LightGBM] [Info] Number of data points in the train set: 535757, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828890
# [LightGBM] [Info] Start training from score -0.679082
# [LightGBM] [Info] Start training from score -2.119934
# [LightGBM] [Info] Start training from score -1.352045
# [LightGBM] [Info] Start training from score -2.475641
# [LightGBM] [Info] Start training from score -4.915041
# [LightGBM] [Info] Start training from score -8.680576
# [LightGBM] [Info] Start training from score -7.106937
# This Fold took 1.09 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.025429 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2511
# [LightGBM] [Info] Number of data points in the train set: 535757, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828890
# [LightGBM] [Info] Start training from score -0.679082
# [LightGBM] [Info] Start training from score -2.119919
# [LightGBM] [Info] Start training from score -1.352045
# [LightGBM] [Info] Start training from score -2.475664
# [LightGBM] [Info] Start training from score -4.915041
# [LightGBM] [Info] Start training from score -8.680576
# [LightGBM] [Info] Start training from score -7.106937
# This Fold took 1.1 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.039160 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2523
# [LightGBM] [Info] Number of data points in the train set: 535757, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828890
# [LightGBM] [Info] Start training from score -0.679082
# [LightGBM] [Info] Start training from score -2.119919
# [LightGBM] [Info] Start training from score -1.352045
# [LightGBM] [Info] Start training from score -2.475664
# [LightGBM] [Info] Start training from score -4.915041
# [LightGBM] [Info] Start training from score -8.680576
# [LightGBM] [Info] Start training from score -7.106937
# This Fold took 1.09 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.157932 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2515
# [LightGBM] [Info] Number of data points in the train set: 535757, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828804
# [LightGBM] [Info] Start training from score -0.679082
# [LightGBM] [Info] Start training from score -2.119919
# [LightGBM] [Info] Start training from score -1.352045
# [LightGBM] [Info] Start training from score -2.475664
# [LightGBM] [Info] Start training from score -4.915041
# [LightGBM] [Info] Start training from score -8.680576
# [LightGBM] [Info] Start training from score -7.109217
# This Fold took 1.19 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.024749 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2518
# [LightGBM] [Info] Number of data points in the train set: 535757, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828804
# [LightGBM] [Info] Start training from score -0.679082
# [LightGBM] [Info] Start training from score -2.119919
# [LightGBM] [Info] Start training from score -1.352045
# [LightGBM] [Info] Start training from score -2.475664
# [LightGBM] [Info] Start training from score -4.915041
# [LightGBM] [Info] Start training from score -8.680576
# [LightGBM] [Info] Start training from score -7.109217
# This Fold took 1.11 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.027111 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2513
# [LightGBM] [Info] Number of data points in the train set: 535757, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828804
# [LightGBM] [Info] Start training from score -0.679082
# [LightGBM] [Info] Start training from score -2.119934
# [LightGBM] [Info] Start training from score -1.352038
# [LightGBM] [Info] Start training from score -2.475664
# [LightGBM] [Info] Start training from score -4.915041
# [LightGBM] [Info] Start training from score -8.680576
# [LightGBM] [Info] Start training from score -7.109217
# This Fold took 1.11 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.056126 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2518
# [LightGBM] [Info] Number of data points in the train set: 535757, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828804
# [LightGBM] [Info] Start training from score -0.679082
# [LightGBM] [Info] Start training from score -2.119934
# [LightGBM] [Info] Start training from score -1.352038
# [LightGBM] [Info] Start training from score -2.475664
# [LightGBM] [Info] Start training from score -4.915041
# [LightGBM] [Info] Start training from score -8.680576
# [LightGBM] [Info] Start training from score -7.109217
# This Fold took 1.09 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.048693 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2509
# [LightGBM] [Info] Number of data points in the train set: 535757, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828890
# [LightGBM] [Info] Start training from score -0.679082
# [LightGBM] [Info] Start training from score -2.119934
# [LightGBM] [Info] Start training from score -1.352038
# [LightGBM] [Info] Start training from score -2.475664
# [LightGBM] [Info] Start training from score -4.914787
# [LightGBM] [Info] Start training from score -8.680576
# [LightGBM] [Info] Start training from score -7.109217
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# This Fold took 1.1 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.025790 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2520
# [LightGBM] [Info] Number of data points in the train set: 535757, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828890
# [LightGBM] [Info] Start training from score -0.679082
# [LightGBM] [Info] Start training from score -2.119934
# [LightGBM] [Info] Start training from score -1.352038
# [LightGBM] [Info] Start training from score -2.475664
# [LightGBM] [Info] Start training from score -4.914787
# [LightGBM] [Info] Start training from score -8.691626
# [LightGBM] [Info] Start training from score -7.106937
# This Fold took 1.09 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.021996 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2509
# [LightGBM] [Info] Number of data points in the train set: 535757, number of used features: 47
# [LightGBM] [Info] Start training from score -3.828890
# [LightGBM] [Info] Start training from score -0.679082
# [LightGBM] [Info] Start training from score -2.119934
# [LightGBM] [Info] Start training from score -1.352038
# [LightGBM] [Info] Start training from score -2.475664
# [LightGBM] [Info] Start training from score -4.914787
# [LightGBM] [Info] Start training from score -8.691626
# [LightGBM] [Info] Start training from score -7.106937
# This Fold took 1.11 minutes

# %%
models = [XGB_freq_no_out_15f, XGB_freq_out_15f, 
          XGB_count_no_out_15f, XGB_count_out_15f,
          RF_freq_no_out_15f, RF_freq_out_15f,
          RF_count_no_out_15f, RF_count_out_15f,
          LGBM_freq_no_out_15f, LGBM_freq_out_15f,
          LGBM_count_no_out_15f, LGBM_count_out_15f]

model_names = ['XGB_freq_no_out_15f', 'XGB_freq_out_15f', 
               'XGB_count_no_out_15f', 'XGB_count_out_15f',
               'RF_freq_no_out_15f', 'RF_freq_out_15f',
               'RF_count_no_out_15f', 'RF_count_out_15f',
               'LGBM_freq_no_out_15f', 'LGBM_freq_out_15f',
               'LGBM_count_no_out_15f', 'LGBM_count_out_15f']

m.metrics2(models, model_names)
# Out:
#                      XGB_freq_no_out_15f XGB_freq_out_15f  \
# Train F1 macro             0.664+/-0.001    0.663+/-0.002
# Validation F1 macro        0.455+/-0.007    0.454+/-0.007
# Precision Train            0.834+/-0.002    0.831+/-0.003
# Precision Validation       0.568+/-0.021    0.569+/-0.027
# Recall Train               0.648+/-0.003    0.646+/-0.002
# Recall Validation          0.438+/-0.009    0.436+/-0.009
# Time                       1.535+/-0.028    1.451+/-0.027
#
#                      XGB_count_no_out_15f XGB_count_out_15f  \
# Train F1 macro              0.664+/-0.001     0.663+/-0.002
# Validation F1 macro          0.451+/-0.01     0.456+/-0.009
# Precision Train             0.833+/-0.002      0.83+/-0.002
# Precision Validation        0.567+/-0.028     0.575+/-0.018
# Recall Train                0.648+/-0.002     0.647+/-0.003
# Recall Validation            0.435+/-0.01      0.438+/-0.01
# Time                        1.206+/-0.005       1.2+/-0.009
#
#                      RF_freq_no_out_15f RF_freq_out_15f RF_count_no_out_15f  \
# Train F1 macro                1.0+/-0.0       1.0+/-0.0           1.0+/-0.0
# Validation F1 macro       0.392+/-0.007   0.392+/-0.008       0.394+/-0.009
# Precision Train               1.0+/-0.0       1.0+/-0.0           1.0+/-0.0
# Precision Validation       0.53+/-0.061   0.529+/-0.048        0.53+/-0.044
# Recall Train                  1.0+/-0.0       1.0+/-0.0           1.0+/-0.0
# Recall Validation         0.378+/-0.004   0.377+/-0.004       0.379+/-0.005
# Time                      4.833+/-0.092   4.645+/-0.077       4.765+/-0.153
#
#                      RF_count_out_15f LGBM_freq_no_out_15f LGBM_freq_out_15f  \
# Train F1 macro              1.0+/-0.0        0.421+/-0.011     0.423+/-0.017
# Validation F1 macro     0.392+/-0.011        0.395+/-0.008     0.397+/-0.009
# Precision Train             1.0+/-0.0        0.501+/-0.022     0.502+/-0.029
# Precision Validation    0.523+/-0.046        0.441+/-0.012     0.444+/-0.014
# Recall Train                1.0+/-0.0        0.426+/-0.013      0.426+/-0.02
# Recall Validation       0.378+/-0.006        0.404+/-0.014     0.405+/-0.014
# Time                    4.411+/-0.148        1.369+/-0.013     1.359+/-0.015
#
#                      LGBM_count_no_out_15f LGBM_count_out_15f
# Train F1 macro               0.417+/-0.009       0.41+/-0.009
# Validation F1 macro          0.392+/-0.008      0.388+/-0.008
# Precision Train               0.49+/-0.019      0.488+/-0.018
# Precision Validation         0.437+/-0.013       0.438+/-0.01
# Recall Train                 0.421+/-0.011      0.412+/-0.015
# Recall Validation            0.398+/-0.013      0.391+/-0.012
# Time                         1.116+/-0.029      1.104+/-0.024

# %% [markdown]
# **XGB, RF, LGBM & HGBoost with integrated Over/Undersampling**

# %%
method = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# %%
params = {'XGB': {'learning_rate': 0.4, 'n_estimators': 200}}

# %%
filtered_XGB_params_10f = mod.k_fold(method, X, y, test1, 'XGB', params = params, 
              enc = 'count', outliers = True, col = cols,
              file_name = 'filtered_XGB_params_10f_2',
              under_sample = False, over_sample = False)

filtered_RF_10f = mod.k_fold(method, X, y, test1, 'RF', params = {}, 
              enc = 'count', outliers = True, col = cols,
              file_name = 'filtered_RF_10f',
              under_sample = False, over_sample = False)

filtered_LGBM_10f = mod.k_fold(method, X, y, test1, 'LGBM', params = {}, 
              enc = 'count', outliers = True, col = cols,
              file_name = 'filtered_LGBM_10f',
              under_sample = False, over_sample = False)
# Out:
# This Fold took 1.87 minutes
# This Fold took 1.92 minutes
# This Fold took 1.98 minutes
# This Fold took 1.87 minutes
# This Fold took 1.79 minutes
# This Fold took 1.81 minutes
# This Fold took 1.95 minutes
# This Fold took 1.86 minutes
# This Fold took 1.92 minutes
# This Fold took 1.83 minutes
# This Fold took 5.35 minutes
# This Fold took 5.5 minutes
# This Fold took 5.4 minutes
# This Fold took 5.45 minutes
# This Fold took 5.33 minutes
# This Fold took 5.41 minutes
# This Fold took 5.43 minutes
# This Fold took 5.36 minutes
# This Fold took 31.18 minutes
# This Fold took 5.21 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.033812 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2437
# [LightGBM] [Info] Number of data points in the train set: 511530, number of used features: 36
# [LightGBM] [Info] Start training from score -3.876364
# [LightGBM] [Info] Start training from score -0.676628
# [LightGBM] [Info] Start training from score -2.114442
# [LightGBM] [Info] Start training from score -1.357571
# [LightGBM] [Info] Start training from score -2.469993
# [LightGBM] [Info] Start training from score -4.908476
# [LightGBM] [Info] Start training from score -8.690814
# [LightGBM] [Info] Start training from score -7.102529
# This Fold took 1.34 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.029313 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2439
# [LightGBM] [Info] Number of data points in the train set: 511595, number of used features: 36
# [LightGBM] [Info] Start training from score -3.874324
# [LightGBM] [Info] Start training from score -0.676694
# [LightGBM] [Info] Start training from score -2.114423
# [LightGBM] [Info] Start training from score -1.357630
# [LightGBM] [Info] Start training from score -2.469912
# [LightGBM] [Info] Start training from score -4.908868
# [LightGBM] [Info] Start training from score -8.690941
# [LightGBM] [Info] Start training from score -7.102656
# This Fold took 1.33 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019182 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2440
# [LightGBM] [Info] Number of data points in the train set: 511531, number of used features: 36
# [LightGBM] [Info] Start training from score -3.877309
# [LightGBM] [Info] Start training from score -0.676661
# [LightGBM] [Info] Start training from score -2.114460
# [LightGBM] [Info] Start training from score -1.357497
# [LightGBM] [Info] Start training from score -2.469787
# [LightGBM] [Info] Start training from score -4.908213
# [LightGBM] [Info] Start training from score -8.690816
# [LightGBM] [Info] Start training from score -7.102531
# This Fold took 1.33 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.028299 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2437
# [LightGBM] [Info] Number of data points in the train set: 511562, number of used features: 36
# [LightGBM] [Info] Start training from score -3.875766
# [LightGBM] [Info] Start training from score -0.676599
# [LightGBM] [Info] Start training from score -2.114407
# [LightGBM] [Info] Start training from score -1.357702
# [LightGBM] [Info] Start training from score -2.469940
# [LightGBM] [Info] Start training from score -4.908804
# [LightGBM] [Info] Start training from score -8.690877
# [LightGBM] [Info] Start training from score -7.102591
# This Fold took 1.33 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.034901 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2440
# [LightGBM] [Info] Number of data points in the train set: 511563, number of used features: 36
# [LightGBM] [Info] Start training from score -3.877277
# [LightGBM] [Info] Start training from score -0.676658
# [LightGBM] [Info] Start training from score -2.114555
# [LightGBM] [Info] Start training from score -1.357529
# [LightGBM] [Info] Start training from score -2.469641
# [LightGBM] [Info] Start training from score -4.908011
# [LightGBM] [Info] Start training from score -8.679318
# [LightGBM] [Info] Start training from score -7.100221
# This Fold took 1.41 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.029271 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2439
# [LightGBM] [Info] Number of data points in the train set: 511549, number of used features: 36
# [LightGBM] [Info] Start training from score -3.875269
# [LightGBM] [Info] Start training from score -0.676558
# [LightGBM] [Info] Start training from score -2.114495
# [LightGBM] [Info] Start training from score -1.357783
# [LightGBM] [Info] Start training from score -2.470007
# [LightGBM] [Info] Start training from score -4.908249
# [LightGBM] [Info] Start training from score -8.679291
# [LightGBM] [Info] Start training from score -7.102566
# This Fold took 1.27 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018019 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2438
# [LightGBM] [Info] Number of data points in the train set: 511517, number of used features: 36
# [LightGBM] [Info] Start training from score -3.877093
# [LightGBM] [Info] Start training from score -0.676634
# [LightGBM] [Info] Start training from score -2.114546
# [LightGBM] [Info] Start training from score -1.357477
# [LightGBM] [Info] Start training from score -2.469944
# [LightGBM] [Info] Start training from score -4.908716
# [LightGBM] [Info] Start training from score -8.679228
# [LightGBM] [Info] Start training from score -7.100131
# This Fold took 1.12 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.021315 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2439
# [LightGBM] [Info] Number of data points in the train set: 511587, number of used features: 36
# [LightGBM] [Info] Start training from score -3.875438
# [LightGBM] [Info] Start training from score -0.676636
# [LightGBM] [Info] Start training from score -2.114780
# [LightGBM] [Info] Start training from score -1.357470
# [LightGBM] [Info] Start training from score -2.470058
# [LightGBM] [Info] Start training from score -4.908058
# [LightGBM] [Info] Start training from score -8.679365
# [LightGBM] [Info] Start training from score -7.102640
# This Fold took 1.06 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015912 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2442
# [LightGBM] [Info] Number of data points in the train set: 511582, number of used features: 36
# [LightGBM] [Info] Start training from score -3.875805
# [LightGBM] [Info] Start training from score -0.676626
# [LightGBM] [Info] Start training from score -2.114527
# [LightGBM] [Info] Start training from score -1.357536
# [LightGBM] [Info] Start training from score -2.470118
# [LightGBM] [Info] Start training from score -4.908578
# [LightGBM] [Info] Start training from score -8.690916
# [LightGBM] [Info] Start training from score -7.102630
# This Fold took 0.96 minutes
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017137 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2438
# [LightGBM] [Info] Number of data points in the train set: 511575, number of used features: 36
# [LightGBM] [Info] Start training from score -3.876169
# [LightGBM] [Info] Start training from score -0.676697
# [LightGBM] [Info] Start training from score -2.114676
# [LightGBM] [Info] Start training from score -1.357347
# [LightGBM] [Info] Start training from score -2.469965
# [LightGBM] [Info] Start training from score -4.908564
# [LightGBM] [Info] Start training from score -8.690902
# [LightGBM] [Info] Start training from score -7.102617
# This Fold took 0.97 minutes

# %%
filtered_HGBoost_10f = mod.k_fold(method, X, y, test1, 'HGBoost', params = {}, 
              enc = 'count', outliers = True, col = cols,
              file_name = 'filtered_HGBoost_10f',
              under_sample = False, over_sample = False)

# %%
models = [filtered_XGB_params_10f, filtered_RF_10f, 
          filtered_LGBM_10f, filtered_HGBoost_10f]

model_names = ['XGB', 'RF', 'LGBM', 'HGBoost']


compare_models = m.metrics2(models, model_names)
v.plot_metrics_kfold(compare_models)

# %% [markdown]
# **XGB Classifier Optimisation**

# %%
method = StratifiedKFold(n_splits=15, shuffle=True, random_state=42)

# %%
params = {'XGB': {'learning_rate': 0.4, 'n_estimators': 200}}

# %%
# XGB_params_all_feat = mod.k_fold(method, X, y, test1, 'XGB', params = params,
#               enc = 'count', outliers = True,
#               file_name = None,
#               under_sample = False, over_sample = False)

# XGB_simple_all_feat = mod.k_fold(method, X, y, test1, 'XGB', params = {},
#               enc = 'count', outliers = True,
#               file_name = None,
#               under_sample = False, over_sample = False)
# Out:
# Claim Injury Type
# 1    231136
# 3    116985
# 2     54892
# 4     38464
# 0      9442
# 5      3357
# 7       374
# 6        77
# Name: count, dtype: int64
# This Fold took 1.84 minutes
# Claim Injury Type
# 1    231136
# 3    116976
# 2     54888
# 4     38469
# 0      9418
# 5      3356
# 7       374
# 6        77
# Name: count, dtype: int64
# This Fold took 2.4 minutes
# Claim Injury Type
# 1    231157
# 3    116967
# 2     54880
# 4     38474
# 0      9423
# 5      3360
# 7       375
# 6        78
# Name: count, dtype: int64
# This Fold took 2.56 minutes
# Claim Injury Type
# 1    231140
# 3    117010
# 2     54863
# 4     38458
# 0      9424
# 5      3358
# 7       375
# 6        76
# Name: count, dtype: int64
# This Fold took 2.28 minutes
# Claim Injury Type
# 1    231151
# 3    117034
# 2     54877
# 4     38459
# 0      9429
# 5      3357
# 7       374
# 6        76
# Name: count, dtype: int64
# This Fold took 2.42 minutes
# Claim Injury Type
# 1    231136
# 3    116985
# 2     54892
# 4     38464
# 0      9442
# 5      3357
# 7       374
# 6        77
# Name: count, dtype: int64
# This Fold took 1.39 minutes
# Claim Injury Type
# 1    231136
# 3    116976
# 2     54888
# 4     38469
# 0      9418
# 5      3356
# 7       374
# 6        77
# Name: count, dtype: int64
# This Fold took 1.36 minutes
# Claim Injury Type
# 1    231157
# 3    116967
# 2     54880
# 4     38474
# 0      9423
# 5      3360
# 7       375
# 6        78
# Name: count, dtype: int64
# This Fold took 1.57 minutes
# Claim Injury Type
# 1    231140
# 3    117010
# 2     54863
# 4     38458
# 0      9424
# 5      3358
# 7       375
# 6        76
# Name: count, dtype: int64
# This Fold took 1.4 minutes
# Claim Injury Type
# 1    231151
# 3    117034
# 2     54877
# 4     38459
# 0      9429
# 5      3357
# 7       374
# 6        76
# Name: count, dtype: int64
# This Fold took 1.33 minutes

# %%
models = [XGB_simple_all_feat, XGB_params_all_feat, filtered_XGB_params, filtered_XGB_params_10f]

model_names = ['XGB_simple_all_feat', 'XGB_params_all_feat', 'filtered_XGB_params', 'filtered_XGB_params_10f']

m.metrics2(models, model_names)
# Out:
#                      XGB_simple_all_feat XGB_params_all_feat  \
# Train F1 macro             0.672+/-0.001       0.768+/-0.002
# Validation F1 macro        0.451+/-0.003       0.454+/-0.002
# Precision Train            0.839+/-0.002       0.885+/-0.001
# Precision Validation        0.57+/-0.008       0.557+/-0.011
# Recall Train               0.656+/-0.001       0.735+/-0.002
# Recall Validation          0.434+/-0.005       0.434+/-0.003
# Time                        1.41+/-0.084         2.3+/-0.247
#
#                      filtered_XGB_params filtered_XGB_params_10f
# Train F1 macro             0.759+/-0.002           0.749+/-0.002
# Validation F1 macro        0.456+/-0.004           0.457+/-0.006
# Precision Train             0.88+/-0.001           0.875+/-0.001
# Precision Validation       0.561+/-0.006           0.557+/-0.015
# Recall Train               0.728+/-0.002           0.718+/-0.001
# Recall Validation          0.435+/-0.005           0.437+/-0.006
# Time                       2.094+/-0.373           2.309+/-0.161

# %%
# filtered_XGB_params_10f = mod.k_fold(method, X, y, test1, 'XGB', params = params, 
#               enc = 'count', outliers = True, col = cols,
#               file_name = 'filtered_XGB_params_10f',
#               under_sample = False, over_sample = False)

# filtered_XGB_no_params_15f = mod.k_fold(method, X, y, test1, 'XGB', params = {}, 
#               enc = 'count', outliers = True, col = cols,
#               file_name = 'filtered_XGB_no_params_15f',
#               under_sample = False, over_sample = False)

# filtered_XGB_params_freq_15f = mod.k_fold(method, X, y, test1, 'XGB', params = params, 
#               enc = 'freq', outliers = True, col = cols,
#               file_name = 'filtered_XGB_params_freq_15f',
#               under_sample = False, over_sample = False)

# filtered_XGB_no_params_freq_15f = mod.k_fold(method, X, y, test1, 'XGB', params = {}, 
#               enc = 'freq', outliers = True, col = cols,
#               file_name = 'filtered_XGB_no_params_freq_15f',
#               under_sample = False, over_sample = False)
# Out:
# This Fold took 1.45 minutes
# This Fold took 1.43 minutes
# This Fold took 1.47 minutes
# This Fold took 1.42 minutes
# This Fold took 1.45 minutes
# This Fold took 1.47 minutes
# This Fold took 1.43 minutes
# This Fold took 1.29 minutes
# This Fold took 1.31 minutes
# This Fold took 1.31 minutes
# This Fold took 1.32 minutes
# This Fold took 1.32 minutes
# This Fold took 1.31 minutes
# This Fold took 1.23 minutes
# This Fold took 1.52 minutes
# This Fold took 2.15 minutes
# This Fold took 2.3 minutes
# This Fold took 2.61 minutes
# This Fold took 3.38 minutes
# This Fold took 4.12 minutes
# This Fold took 4.19 minutes
# This Fold took 5.68 minutes
# This Fold took 6.17 minutes
# This Fold took 7.41 minutes
# This Fold took 6.35 minutes
# This Fold took 6.18 minutes
# This Fold took 6.07 minutes
# This Fold took 5.1 minutes
# This Fold took 5.98 minutes
# This Fold took 4.87 minutes
# This Fold took 3.44 minutes
# This Fold took 5.03 minutes
# This Fold took 4.83 minutes
# This Fold took 5.01 minutes
# This Fold took 5.98 minutes
# This Fold took 5.51 minutes
# This Fold took 5.97 minutes
# This Fold took 5.62 minutes
# This Fold took 5.31 minutes
# This Fold took 5.5 minutes
# This Fold took 2.29 minutes
# This Fold took 1.63 minutes
# This Fold took 1.56 minutes
# This Fold took 1.46 minutes
# This Fold took 1.27 minutes

# %%
# s.play_('audio.mp3')
# Out:
# Input #0, wav, from '/var/folders/mm/fxsq_1490x9dd2w76tqvt3kr0000gn/T/tmp8lvmr5op.wav':
#   Duration: 00:00:10.00, bitrate: 1536 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 2 channels, s16, 1536 kb/s
#    9.93 M-A:  0.000 fd=   0 aq=    0KB vq=    0KB sq=    0B

# %%
models = [filtered_XGB_no_params_15f, filtered_XGB_params_freq_15f, filtered_XGB_no_params_freq_15f]

model_names = ['filtered_XGB_no_params_15f', 'filtered_XGB_params_freq_15f', 'filtered_XGB_no_params_freq_15f']

m.metrics2(models, model_names)
# Out:
#                      filtered_XGB_no_params_15f filtered_XGB_params_freq_15f  \
# Train F1 macro                    0.658+/-0.002                0.745+/-0.001
# Validation F1 macro               0.457+/-0.011                0.456+/-0.007
# Precision Train                   0.829+/-0.002                0.874+/-0.001
# Precision Validation              0.586+/-0.038                0.556+/-0.016
# Recall Train                       0.64+/-0.003                0.715+/-0.001
# Recall Validation                  0.439+/-0.01                0.437+/-0.008
# Time                              1.382+/-0.084                4.837+/-1.587
#
#                      filtered_XGB_no_params_freq_15f
# Train F1 macro                         0.657+/-0.002
# Validation F1 macro                     0.451+/-0.01
# Precision Train                        0.828+/-0.002
# Precision Validation                   0.567+/-0.024
# Recall Train                            0.64+/-0.002
# Recall Validation                      0.435+/-0.011
# Time                                   4.027+/-1.792
